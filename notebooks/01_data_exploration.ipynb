# %% [markdown]
# # 01 Data Exploration
# Exploración inicial de archivos Olist/Ecommify.

# %%
import pandas as pd
from pathlib import Path
DATA_DIR = Path('../data/raw')
files = list(DATA_DIR.glob('*.csv'))
[(f.name, pd.read_csv(f).shape) for f in files]
