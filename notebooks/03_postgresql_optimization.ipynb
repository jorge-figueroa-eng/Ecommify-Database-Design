# %% [markdown]
# # 03 PostgreSQL Optimization
# Ejecución de EXPLAIN ANALYZE antes/después.

# %%
print('Ejecutar archivos en postgresql/explain/before y postgresql/explain/after; llenar evidences/postgresql/postgresql_metrics.csv')
