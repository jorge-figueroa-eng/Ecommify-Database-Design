# %% [markdown]
# # 06 Generate Charts and Metrics
# Generación de gráficas a partir de métricas reales.

# %%
import sys
sys.path.append('../scripts')
print('Usar scripts/calculate_improvement.py y scripts/generate_metrics_charts.py')
